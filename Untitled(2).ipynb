# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
pd.set_option('display.max_columns', 30)
import math

# %%
data = pd.read_csv("trainfx.csv")

# %%
data.head()

# %%
data1= pd.read_csv("testfx.csv")
data1.head()

# %%
wt=pd.read_csv("submission.csv",index_col=0)

# %%
wt.head(12)

# %%
data["temp"] = data["month"].map(wt["temp"])

# %%
data.head(50)

# %%
data1["temp"] = data1["month"].map(wt["temp"])

# %%
data1.head()

# %%
t=pd.read_csv("ftemp.csv",index_col=0)

# %%
t.head()

# %%
wer=pd.read_csv("x_test.csv")

# %%
wer.head()

# %%
data1["date"]=wer["date key sélection"]

# %%
data1["temp2"] = data1["date"].map(t["temp"])

# %%
data1.head()

# %%
label = pd.read_csv('y_train.csv', index_col=0)
label.head()
# Out:
#                              delta selection-departure  \
# emergency vehicle selection
# 5105452                                             86
# 4720915                                            164
# 5365374                                            125
# 4741586                                            168
# 5381209                                            138
#
#                              delta departure-presentation  \
# emergency vehicle selection
# 5105452                                               324
# 4720915                                               297
# 5365374                                               365
# 4741586                                               160
# 5381209                                               523
#
#                              delta selection-presentation
# emergency vehicle selection
# 5105452                                               410
# 4720915                                               461
# ...

# %%
data_nan = (data.isnull().sum()/data.shape[0])*100
data_nan[data_nan>0]
# Out:
# Series([], dtype: float64)

# %%
data['pred1']=label['delta selection-departure'].values

# %%
data['pred2']=label['delta departure-presentation'].values

# %%
y1=data['pred1']
y2=data['pred2']
X=data.drop(['pred1','pred2'],axis=1)
X.head()
# Out:
#    alert reason category  alert reason  intervention on public roads  floor  \
# 0                      3          2162                             0      0
# 1                      3          2124                             0      1
# 2                      3          2163                             0      2
# 3                      3          2162                             0      0
# 4                      3          2162                             0      3
#
#    longitude intervention  latitude intervention  emergency vehicle type  \
# 0                2.284796              48.879669                      69
# 1                2.247464              48.818191                      27
# 2                2.258328              48.836759                      69
# 3                2.393832              48.776526                      69
# 4                2.458610              48.875751                      69
#
#    rescue center  time key sélection  status preceding selection  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size=0.25, random_state=42)

# from sklearn import linear_model
# lasso_reg = linear_model.Lasso(alpha=0.01)
# lasso_reg.fit(X_train, y_train)
# y_pred = lasso_reg.predict(X_test)
# print("Lasso: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# linear_reg = linear_model.LinearRegression()
# linear_reg.fit(X_train, y_train)
# y_pred = linear_reg.predict(X_test)
# print("Linear: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# reg = linear_model.BayesianRidge()
# reg.fit(X_train, y_train)
# y_pred = reg.predict(X_test)
# print("Bayesian: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# reg = linear_model.ElasticNet()
# reg.fit(X_train, y_train)
# y_pred = reg.predict(X_test)
# print("ElasticNet: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# from sklearn.ensemble import RandomForestRegressor
# from sklearn.datasets import make_regression

# regr = RandomForestRegressor(random_state=0, n_estimators=100)
# regr.fit(X_train, y_train)

# y_pred = regr.predict(X_test)
# print("Random Forest: ",mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

import xgboost as xgb
data_dmatrix = xgb.DMatrix(data=X_train,label=y_train)
xg_reg = xgb.XGBRegressor(learning_rate = 0.1, n_estimators =300)
xg_reg.fit(X_train,y_train)

y_pred = xg_reg.predict(X_test)
print("XGBR: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# import matplotlib.pyplot as plt

# xgb.plot_importance(xg_reg)
# plt.figure(figsize=(4,4))
# plt.show()
# Out:
# C:\Users\shiva\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:52:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBR:  36.446677531206454 0.07097136675048943

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y2, test_size=0.25, random_state=42)

# from sklearn import linear_model
# lasso_reg = linear_model.Lasso(alpha=0.01)
# lasso_reg.fit(X_train, y_train)
# y_pred = lasso_reg.predict(X_test)
# print("Lasso: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# linear_reg = linear_model.LinearRegression()
# linear_reg.fit(X_train, y_train)
# y_pred = linear_reg.predict(X_test)
# print("Linear: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# reg = linear_model.BayesianRidge()
# reg.fit(X_train, y_train)
# y_pred = reg.predict(X_test)
# print("Bayesian: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# reg = linear_model.ElasticNet()
# reg.fit(X_train, y_train)
# y_pred = reg.predict(X_test)
# print("ElasticNet: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# from sklearn.ensemble import RandomForestRegressor
# from sklearn.datasets import make_regression

# regr = RandomForestRegressor(random_state=0, n_estimators=200)
# regr.fit(X_train, y_train)

# y_pred = regr.predict(X_test)
# print("Random Forest: ",mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

import xgboost as xgb
data_dmatrix = xgb.DMatrix(data=X_train,label=y_train)
xg_reg = xgb.XGBRegressor(learning_rate = 0.1, n_estimators = 80)
xg_reg.fit(X_train,y_train)

y_pred = xg_reg.predict(X_test)
print("XGBR: ", mean_absolute_error(y_pred, y_test), r2_score(y_test, y_pred))

# import matplotlib.pyplot as plt

# xgb.plot_importance(xg_reg)
# plt.figure(figsize=(4,4))
# plt.show()
# Out:
# C:\Users\shiva\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:04:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBR:  88.02132451779276 0.45656645710938304

# %%
import xgboost as xgb
import pandas as pd

test = pd.read_csv('testfx.csv')
test=test.drop(['Unnamed: 0'],axis=1)
# test['location of the event'].fillna(test['location of the event'].mode()[0], inplace=True)
data = pd.read_csv('trainfx12.csv')

X = data
y = label['delta selection-departure']

data_dmatrix = xgb.DMatrix(data=X,label=y)
xg_reg = xgb.XGBRegressor(learning_rate = 0.1, n_estimators = 200)
xg_reg.fit(X,y)

y_pred1 = xg_reg.predict(test)
print(y_pred1)

X['delta selection-departure'] = label['delta selection-departure'].values
y = label['delta departure-presentation']

data_dmatrix = xgb.DMatrix(data=X,label=y)
xg_reg = xgb.XGBRegressor(learning_rate = 0.1, n_estimators = 200)
xg_reg.fit(X,y)

test['delta selection-departure'] = y_pred1
y_pred2 = xg_reg.predict(test)
print(y_pred2)

# %%
sub = pd.DataFrame(columns=['emergency vehicle selection', 'delta selection-departure', 'delta departure-presentation', 'delta selection-presentation'])

# %%
ids = pd.read_csv("x_test.csv")
sub['emergency vehicle selection'] = ids['emergency vehicle selection'].values
ids.head()

# %%
sub['delta selection-departure'] = y_pred1
sub['delta departure-presentation'] = y_pred2
sub['delta selection-presentation'] = sub['delta selection-departure'] + sub['delta departure-presentation']

# %%
sub.head()
# Out:
#    emergency vehicle selection  delta selection-departure  \
# 0                      5271704                 130.630432
# 1                      5092931                 129.845810
# 2                      5153756                 130.630432
# 3                      5355572                 173.749481
# 4                      5178915                 131.005798
#
#    delta departure-presentation  delta selection-presentation
# 0                    425.098145                    555.728577
# 1                    330.100983                    459.946777
# 2                    234.712204                    365.342651
# 3                    257.200775                    430.950256
# 4                    279.394073                    410.399872

# %%
sub.isnull().any()
# Out:
# emergency vehicle selection     False
# delta selection-departure       False
# delta departure-presentation    False
# delta selection-presentation    False
# dtype: bool

# %%
sub.to_csv('submission90.csv', index=False)

# %%
data.shape
# Out:
# (219337, 25)

# %%
from scipy import stats
data=data[(np.abs(stats.zscore(data)) < 23).all(axis=1)]

# %%
data.shape

# %%
dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result:", distance)
print("Should be:", 278.546, "km")

# %%
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

data1['lat1']=np.radians(data1['latitude intervention'])
data1['lon1']=np.radians(data1['longitude intervention'])
data1['lat2']=np.radians(data1['latitude before departure'])
data1['lon2']=np.radians(data1['longitude before departure'])

# %%
data.head()

# %%
data1['dlon'] = data1['lon2'] - data1['lon1']
data1['dlat'] = data1['lat2'] - data1['lat1']

# %%
data1['a'] = np.sin(data1['dlat'] / 2)**2 + np.cos(data1['lat1']) * np.cos(data1['lat2']) * np.sin(data1['dlon'] / 2)**2
data1['c'] = 2 * np.arctan2(np.sqrt(data1['a']), np.sqrt(1 - data1['a']))

# %%
data1['distance'] = R * data1['c']

# %%
data1.head()

# %%
data=data.drop(['Unnamed: 0'],axis=1)

# %%
data1.head()

# %%
data1.to_csv("testfx.csv",index=False)

# %%
data1['distance']=data1['distance']*1000

# %%
data1.head()

# %%
data.head()
# Out:
#    alert reason category  alert reason  intervention on public roads  floor  \
# 0                      3          2162                             0      0
# 1                      3          2124                             0      1
# 2                      3          2163                             0      2
# 3                      3          2162                             0      0
# 4                      3          2162                             0      3
#
#    longitude intervention  latitude intervention  emergency vehicle type  \
# 0                2.284796              48.879669                      69
# 1                2.247464              48.818191                      27
# 2                2.258328              48.836759                      69
# 3                2.393832              48.776526                      69
# 4                2.458610              48.875751                      69
#
#    rescue center  time key sélection  status preceding selection  \
# ...

# %%
data['time elapsed between selection and last observed GPS position']=data['distance'] / 5

# %%
data.head()
# Out:
#    alert reason category  alert reason  intervention on public roads  floor  \
# 0                      3          2162                             0      0
# 1                      3          2124                             0      1
# 2                      3          2163                             0      2
# 3                      3          2162                             0      0
# 4                      3          2162                             0      3
#
#    longitude intervention  latitude intervention  emergency vehicle type  \
# 0                2.284796              48.879669                      69
# 1                2.247464              48.818191                      27
# 2                2.258328              48.836759                      69
# 3                2.393832              48.776526                      69
# 4                2.458610              48.875751                      69
#
#    rescue center  time key sélection  status preceding selection  \
# ...

# %%
data.to_csv('trainfx12.csv',index=False)
